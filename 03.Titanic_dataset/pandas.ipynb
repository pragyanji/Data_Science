# %%
import pandas as pd

# %%
data = pd.read_csv('Titanic.csv')

# %%
print(f'Null values in Age column: {data["Age"].isnull().sum()}')
# Out:
# Null values in Age column: 0

# %%
data['Age'] = data['Age'].fillna(data['Age'].mean())

# %%
data.drop(columns=['Cabin','Ticket'], inplace=True)

# %%
data['Sex'] = data['Sex'].map({'male': 0, 'female': 1})
data.rename(columns={'Sex': 'Gender'}, inplace=True)

# %%
female_business_class = data[(data['Gender'] == 1) & (data['Pclass'] == 1)]

# %%
survived_passengers_in_business_class = data[(data['Survived'] == 1) & (data['Pclass'] == 1)]

# %%
survival_rate_by_class = data.groupby('Pclass')['Survived'].mean()

# %%
filtered_data = data.loc[data['Age'] > 30, ['Name', 'Age', 'Fare']]
print('Passengers older than 30:')
filtered_data
# Out:
# Passengers older than 30:
#                                                   Name   Age     Fare
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  71.2833
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  53.1000
# 4                             Allen, Mr. William Henry  35.0   8.0500
# 6                              McCarthy, Mr. Timothy J  54.0  51.8625
# 11                            Bonnell, Miss. Elizabeth  58.0  26.5500
# ..                                                 ...   ...      ...
# 873                        Vander Cruyssen, Mr. Victor  47.0   9.0000
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0  83.1583
# 881                                 Markun, Mr. Johann  33.0   7.8958
# 885               Rice, Mrs. William (Margaret Norton)  39.0  29.1250
# 890                                Dooley, Mr. Patrick  32.0   7.7500
#
# [305 rows x 3 columns]

# %%
data['Family_Size'] = data['SibSp'] + data['Parch'] + 1
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender        Age  \
# 0                              Braund, Mr. Owen Harris       0  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1  38.000000
# 2                               Heikkinen, Miss. Laina       1  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  35.000000
# 4                             Allen, Mr. William Henry       0  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
data['Title'] = data['Name'].str.split(',').str[1].str.split('.').str[0].str.strip()
data[['Title','Name']].head(50)
# Out:
#      Title                                               Name
# 0       Mr                            Braund, Mr. Owen Harris
# 1      Mrs  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2     Miss                             Heikkinen, Miss. Laina
# 3      Mrs       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       Mr                           Allen, Mr. William Henry
# 5       Mr                                   Moran, Mr. James
# 6       Mr                            McCarthy, Mr. Timothy J
# 7   Master                     Palsson, Master. Gosta Leonard
# 8      Mrs  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9      Mrs                Nasser, Mrs. Nicholas (Adele Achem)
# 10    Miss                    Sandstrom, Miss. Marguerite Rut
# 11    Miss                           Bonnell, Miss. Elizabeth
# 12      Mr                     Saundercock, Mr. William Henry
# 13      Mr                        Andersson, Mr. Anders Johan
# ...

# %%
data['Age']= data['Age'].astype(int)
# fill the 0 age with mean age
data['Age'] = data['Age'].replace(0, data['Age'].mean())
data[data['Age']==0]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Gender, Age, SibSp, Parch, Fare, Embarked, Family_Size, Title, Age_Group]
# Index: []

# %%
bins=[0, 12, 18, 60, 100]
labels=['Child', 'Teenager', 'Adult', 'Senior']
data['Age_Group'] = pd.cut(data['Age'],bins=bins, labels = labels)
data[data['Age']<=12 ][['Age','Age_Group']].head(30)
# Out:
#      Age Age_Group
# 7      2     Child
# 10     4     Child
# 16     2     Child
# 24     8     Child
# 43     3     Child
# 50     7     Child
# 58     5     Child
# 59    11     Child
# 63     4     Child
# 119    2     Child
# 125   12     Child
# 147    9     Child
# 164    1     Child
# 165    9     Child
# 171    4     Child
# 172    1     Child
# 182    9     Child
# 183    1     Child
# 184    4     Child
# 193    3     Child
# 205    2     Child
# 233    5     Child
# 237    8     Child
# 261    3     Child
# 278    7     Child
# 297    2     Child
# 340    2     Child
# 348    3     Child
# 374    3     Child
# 381    1     Child

# %%
print(f"null values in Age column: {data['Age'].isnull().sum()}")
# Out:
# null values in Age column: 0

# %%
# fill the 0 age with mean age
data['Age'] = data['Age'].replace(0, data['Age'].mean())
data[data['Age']==0]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Gender, Age, SibSp, Parch, Fare, Embarked, Family_Size, Title, Age_Group]
# Index: []
